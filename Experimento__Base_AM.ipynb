# %% [markdown]
# <a href="https://colab.research.google.com/github/jutourru/portfolio/blob/main/Experimento__Base_AM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
plt.rcParams.update({'figure.figsize': (10, 6)})

# Gráfico 1: Estados
plt.figure(figsize=(10, 6))
estados.plot(kind='bar', color='skyblue')
plt.title("📍 Estados onde mais compram de revendedoras")
plt.xlabel("Estado")
plt.ylabel("Quantidade")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Gráfico 2: Idades
plt.figure(figsize=(10, 6))
idades.plot(kind='bar', color='salmon')
plt.title("🎂 Distribuição de idade - Compradores de revendedoras")
plt.xlabel("Idade")
plt.ylabel("Quantidade")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# Gráfico 3: Redes Sociais
plt.figure(figsize=(12, 6))
uso_redes.plot(kind='barh', color='mediumseagreen')
plt.title("📱 Redes sociais mais usadas - Quem compra de revendedoras")
plt.xlabel("Quantidade de usuários")
plt.ylabel("Rede social")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-41-681d92533670>:14: UserWarning: Glyph 128205 (\N{ROUND PUSHPIN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128205 (\N{ROUND PUSHPIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# <ipython-input-41-681d92533670>:24: UserWarning: Glyph 127874 (\N{BIRTHDAY CAKE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127874 (\N{BIRTHDAY CAKE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# <ipython-input-41-681d92533670>:33: UserWarning: Glyph 128241 (\N{MOBILE PHONE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128241 (\N{MOBILE PHONE}) missing from font(s) DejaVu Sans.
# ...

# %%
# Filtrar quem compra de revendedoras/amigas/conhecidas
compram_revendedora = df[
    df["Q17_5 - Onde você costuma comprar bijuterias, semijoias e joias Revendedora/ amiga/ conhecida"]
    .astype(str).str.lower().str.contains("sim|yes|x|1", na=False)
]

# Perfil por estado (usando a coluna correta)
estados = compram_revendedora["state - Estado"].value_counts().head(10)

# Perfil por idade
idades = compram_revendedora["age - Idade exata"].value_counts().sort_index()

# Análise de redes sociais
redes_sociais_cols = [col for col in df.columns if col.startswith("Q9_")]
uso_redes = compram_revendedora[redes_sociais_cols].apply(
    lambda col: col.astype(str).str.lower().str.contains('sim|yes|x|1', na=False).sum()
).sort_values(ascending=False)

# Exibir os resultados
print("📍 Estados mais comuns:")
print(estados)

print("\n🎂 Distribuição de idades:")
print(idades)

print("\n📱 Redes sociais mais usadas:")
print(uso_redes)
# Out:
# 📍 Estados mais comuns:
# state - Estado
# 1    58
# 3    49
# 2    37
# 4    36
# Name: count, dtype: int64
#
# 🎂 Distribuição de idades:
# age - Idade exata
# 25     4
# 26     4
# 27     7
# 28     9
# 29     7
# 30     9
# 31    11
# 32     5
# 33     5
# 34    12
# 35    12
# 36    12
# 37     4
# 38     6
# 39    10
# 40     4
# 41     4
# 42     9
# 43     3
# 44     4
# 45     3
# 46     2
# 47     3
# 48     4
# 49     5
# 50     1
# 51     6
# 52     3
# 54     1
# 55     3
# 58     1
# 60     2
# 61     1
# 62     1
# 63     1
# 65     1
# 69     1
# Name: count, dtype: int64
#
# 📱 Redes sociais mais usadas:
# Q9_4 - Quais redes sociais você está usando atualmente? WhatsApp       175
# Q9_2 - Quais redes sociais você está usando atualmente? Instagram      165
# Q9_3 - Quais redes sociais você está usando atualmente? Youtube        151
# Q9_1 - Quais redes sociais você está usando atualmente? Facebook       137
# ...

# %%
# Lista das colunas da pergunta Q17
compra_canais_cols = [
    "Q17_1 - Onde você costuma comprar bijuterias, semijoias e joias On-line/ internet/ marketplace / Mercado Livre / Shein",
    "Q17_2 - Onde você costuma comprar bijuterias, semijoias e joias Site da marca na internet",
    "Q17_3 - Onde você costuma comprar bijuterias, semijoias e joias Na página de Instagram da marca",
    "Q17_4 - Onde você costuma comprar bijuterias, semijoias e joias Loja física/ loja de rua/ quiosques em shopping",
    "Q17_5 - Onde você costuma comprar bijuterias, semijoias e joias Revendedora/ amiga/ conhecida",
    "Q17_6 - Onde você costuma comprar bijuterias, semijoias e joias Salão de cabeleireiros",
    "Q17_7 - Onde você costuma comprar bijuterias, semijoias e joias Lojas de roupas/ lojas de departamento (Riachuelo/ Renner / C&A) / lojas de cosméticos",
    "Q17_8 - Onde você costuma comprar bijuterias, semijoias e joias Outros"
]

# Contar quantos responderam positivamente (convertendo para string)
uso_canais = df[compra_canais_cols].apply(
    lambda col: col.astype(str).str.lower().str.contains('sim|yes|x|1', na=False).sum()
)

# Organizar e visualizar
uso_canais = uso_canais.sort_values(ascending=True)

# Plotar gráfico
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))
sns.barplot(x=uso_canais.values, y=uso_canais.index, palette="magma")
plt.title("📍 Onde os entrevistados costumam comprar semijoias/bijuterias")
plt.xlabel("Número de pessoas")
plt.ylabel("Canais de compra")
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-38-846529050bbf>:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=uso_canais.values, y=uso_canais.index, palette="magma")
# <ipython-input-38-846529050bbf>:31: UserWarning: Glyph 128205 (\N{ROUND PUSHPIN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-38-846529050bbf>:31: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128205 (\N{ROUND PUSHPIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Lista das colunas relacionadas ao uso de redes sociais
redes_sociais_cols = [
    'Q9_1 - Quais redes sociais você está usando atualmente? Facebook',
    'Q9_2 - Quais redes sociais você está usando atualmente? Instagram',
    'Q9_3 - Quais redes sociais você está usando atualmente? Youtube',
    'Q9_4 - Quais redes sociais você está usando atualmente? WhatsApp',
    'Q9_5 - Quais redes sociais você está usando atualmente? LinkedIn',
    'Q9_6 - Quais redes sociais você está usando atualmente? Pinterest',
    'Q9_7 - Quais redes sociais você está usando atualmente? Spotify',
    'Q9_8 - Quais redes sociais você está usando atualmente? X / Twitter',
    'Q9_9 - Quais redes sociais você está usando atualmente? Telegram',
    'Q9_10 - Quais redes sociais você está usando atualmente? Threads',
    'Q9_11 - Quais redes sociais você está usando atualmente? Tik Tok',
    'Q9_12 - Quais redes sociais você está usando atualmente? Outras',
    'Q9_13 - Quais redes sociais você está usando atualmente? Nenhuma'
]

# Contar respostas positivas (convertendo para string primeiro)
uso_redes = df[redes_sociais_cols].apply(
    lambda col: col.astype(str).str.lower().str.contains('sim|yes|x|1', na=False).sum()
)

# Ordenar
uso_redes = uso_redes.sort_values(ascending=True)

# Plotar gráfico
plt.figure(figsize=(10,8))
sns.barplot(x=uso_redes.values, y=uso_redes.index, palette='viridis')
plt.title('Uso Atual de Redes Sociais pelos Respondentes')
plt.xlabel('Número de Usuários')
plt.ylabel('Rede Social')
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-37-a704f3599587>:31: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=uso_redes.values, y=uso_redes.index, palette='viridis')

# %%
cross_tab_norm = cross_tab.div(cross_tab.sum(axis=1), axis=0)

cross_tab_norm.plot(kind='bar', stacked=True, figsize=(10,6), colormap='viridis')

plt.title('Distribuição Percentual do Grau de Instrução por Região')
plt.xlabel('Tipo de Região')
plt.ylabel('Proporção')
plt.legend(title='Grau de Instrução', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
cross_tab.plot(kind='bar', stacked=False, figsize=(10,6), colormap='viridis')

plt.title('Distribuição do Grau de Instrução por Tipo de Região')
plt.xlabel('Tipo de Região')
plt.ylabel('Número de Respondentes')
plt.legend(title='Grau de Instrução', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Contagem por faixa etária
faixa_counts = df['age1 - Faixa de idade'].value_counts().sort_index()

# Plotar gráfico de barras
plt.figure(figsize=(8,5))
sns.barplot(x=faixa_counts.index, y=faixa_counts.values, palette='viridis')
plt.title('Distribuição de Respondentes por Faixa Etária')
plt.xlabel('Faixa Etária')
plt.ylabel('Número de Respondentes')
plt.show()
# Out:
# <ipython-input-32-97d7271a3533>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=faixa_counts.index, y=faixa_counts.values, palette='viridis')

# %%
for col in df.columns:
    print(repr(col))
# Out:
# 'owid - owid'
# 'filtro_1 - Você costuma usar semijoias/ joias com qual frequência diária: Diariamente/ no dia a dia'
# 'filtro_2 - Você costuma usar semijoias/ joias com qual frequência diária: Para trabalhar'
# 'filtro_3 - Você costuma usar semijoias/ joias com qual frequência diária: Nos finais de semana'
# 'filtro_4 - Você costuma usar semijoias/ joias com qual frequência diária: Para sair/ eventos'
# 'filtro_5 - Você costuma usar semijoias/ joias com qual frequência diária: Raramente uso semijoias/joias'
# 'filtro_6 - Você costuma usar semijoias/ joias com qual frequência diária: Não uso semijoias/ joias'
# 'gender - Genero'
# 'age - Idade exata'
# 'age1 - Faixa de idade'
# 'sel - NSE'
# 'state - Estado'
# 'Q4 - E em qual tipo de região você mora?'
# 'Q5 - Qual é o seu grau de instrução?'
# 'Q6 - Qual é a sua principal ocupação?'
# 'Q7 - Qual é seu estado civil?'
# 'Q8 - Você tem filhos?'
# 'Q9_1 - Quais redes sociais você está usando atualmente? Facebook'
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Lista das colunas de promoções
promocao_cols = [
    'Q44_1 - Pensando em promoções que a Rommanel poderia fazer, quais são as mais atraentes para você Compre e ganhe outros produtos',
    'Q44_2 - Pensando em promoções que a Rommanel poderia fazer, quais são as mais atraentes para você Pontos em compras/ junte e troque',
    'Q44_3 - Pensando em promoções que a Rommanel poderia fazer, quais são as mais atraentes para você Cashback',
    'Q44_4 - Pensando em promoções que a Rommanel poderia fazer, quais são as mais atraentes para você Sorteio de viagem/ casa/ carro'
]

# Contar as menções para cada promoção
contagem = {}
for col in promocao_cols:
    count = df[col].dropna().count()
    if 'Compre e ganhe' in col:
        nome = 'Compre e ganhe outros produtos'
    elif 'Pontos em compras' in col:
        nome = 'Pontos em compras / junte e troque'
    elif 'Cashback' in col:
        nome = 'Cashback'
    elif 'Sorteio de viagem' in col:
        nome = 'Sorteio de viagem / casa / carro'
    else:
        nome = col
    contagem[nome] = count

labels = list(contagem.keys())
values = list(contagem.values())

plt.figure(figsize=(10,6))
sns.set_style("whitegrid")
palette = sns.color_palette("coolwarm", len(labels))

barplot = sns.barplot(x=values, y=labels, palette=palette)

# Adicionar valores no topo das barras
for i, v in enumerate(values):
    barplot.text(v + 0.5, i, str(v), color='black', va='center', fontweight='bold')

plt.title('Promoções Mais Atraentes para os Respondentes', fontsize=18, weight='bold')
plt.xlabel('Número de Menções', fontsize=14)
plt.ylabel('Tipo de Promoção', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-26-95af1d3f7310>:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(x=values, y=labels, palette=palette)

# %%
# 4. Celebridades/Cantores mais citados
celebridades_cols = [
    'Q44_1 - Pensando em promoções que a Rommanel poderia fazer, quais são as mais atraentes para você Compre e ganhe outros produtos',
    'Q44_2 - Pensando em promoções que a Rommanel poderia fazer, quais são as mais atraentes para você Pontos em compras/ junte e troque',
    'Q44_3 - Pensando em promoções que a Rommanel poderia fazer, quais são as mais atraentes para você Cashback',
    'Q44_4 - Pensando em promoções que a Rommanel poderia fazer, quais são as mais atraentes para você Sorteio de viagem/ casa/ carro',
    'Q44_5 - Que influencers ou celebridades você gosta? Escreva ( para toda a amostra) - Cantores/ músicos:'
]

celebridades = df[celebridades_cols].values.flatten()
celebridades = [str(x).strip().lower() for x in celebridades if pd.notnull(x)]
contagem = Counter(celebridades)
mais_citados = contagem.most_common(10)

print("\n🎤 Cantores/Celebridades mais citados:")
for nome, qtd in mais_citados:
    print(f"- {nome.title()}: {qtd} menções")

# Gráfico de barras
nomes = [nome.title() for nome, _ in mais_citados]
valores = [qtd for _, qtd in mais_citados]

plt.figure(figsize=(10,6))
sns.barplot(x=valores, y=nomes, palette='magma')
plt.title('🎤 Cantores e Celebridades Mais Citados')
plt.xlabel('Número de Menções')
plt.ylabel('Nome')
plt.tight_layout()
plt.show()
# Out:
# 🎤 Cantores/Celebridades mais citados:
# - Nenhum: 41 menções
# - Eliana: 34 menções
# - Virgínia: 27 menções
# - Carlinhos Maia: 25 menções
# - Virginia: 23 menções
# - Luciano Huck: 22 menções
# - Rodrigo Faro: 21 menções
# - Paola Oliveira: 21 menções
# - Gustavo Lima: 21 menções
# - Simone Mendes: 17 menções
# <ipython-input-13-16c1e87bd864>:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=valores, y=nomes, palette='magma')
# <ipython-input-13-16c1e87bd864>:28: UserWarning: Glyph 127908 (\N{MICROPHONE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127908 (\N{MICROPHONE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 3. Correlação entre variáveis numéricas
df_numeric = df.select_dtypes(include=['int64', 'float64'])
corr = df_numeric.corr()

plt.figure(figsize=(16, 10))
sns.heatmap(corr, cmap='coolwarm', annot=False)
plt.title('🔗 Mapa de Correlação entre Variáveis Numéricas')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128279 (\N{LINK SYMBOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 2. Visão geral
print("🔍 Dimensões da base:", df.shape)
display(df.head())
# Out:
# 🔍 Dimensões da base: (310, 296)
#                         owid - owid  \
# 0  769d90c16f576f22007f9ad2b235d22a
# 1  9252898f26f042a492b2866b028963db
# 2  dc4a2047e105752fd20c5ac133118e23
# 3  066f771cfb09e4ed896860c62705812a
# 4  6afd066ff8643481d48340c11d4c3985
#
#    filtro_1 - Você costuma usar semijoias/ joias com qual frequência diária: Diariamente/ no dia a dia  \
# 0                                                NaN
# 1                                                1.0
# 2                                                1.0
# 3                                                NaN
# 4                                                1.0
#
#    filtro_2 - Você costuma usar semijoias/ joias com qual frequência diária: Para trabalhar  \
# 0                                                NaN
# 1                                                NaN
# 2                                                1.0
# 3                                                1.0
# ...

# %%
# 1. Leitura da base
df = pd.read_excel('/content/base01.xlsx')

# %%
sns.set(style='whitegrid')
plt.rcParams["figure.figsize"] = (12, 6)

# Upload (caso necessário)
# from google.colab import files
# uploaded = files.upload()

# %%
# Importações
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import plotly.express as px
from IPython.display import display

# %%
import pandas as pd

# Caminho da base
df = pd.read_excel('/content/base01.xlsx')

# %%
file_path = '/content/base01.xlsx'
